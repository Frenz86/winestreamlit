# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('wine_dataset.csv')

# %%
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df.rename(columns={'type':'wine_type'},inplace=True)
df.head()
# Out:
#   wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36            20.7
# 1     white            6.3              0.30         0.34             1.6
# 2     white            8.1              0.28         0.40             6.9
# 3     white            7.2              0.23         0.32             8.5
# 4     white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
print(f'Data Frame Shape (rows, columns): {df.shape}')
# Out:
# Data Frame Shape (rows, columns): (6497, 13)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
len(df.quality.unique())
# Out:
# 7

# %%
Sum = df.isnull().sum()
Percentage = ( df.isnull().sum()/df.isnull().count())

pd.concat([Sum,Percentage], axis =1, keys= ['Sum', 'Percentage'])
# Out:
#                       Sum  Percentage
# wine_type               0    0.000000
# fixed acidity          10    0.001539
# volatile acidity        8    0.001231
# citric acid             3    0.000462
# residual sugar          2    0.000308
# chlorides               2    0.000308
# free sulfur dioxide     0    0.000000
# total sulfur dioxide    0    0.000000
# density                 0    0.000000
# pH                      9    0.001385
# sulphates               4    0.000616
# alcohol                 0    0.000000
# quality                 0    0.000000

# %%
df.head()
# Out:
#   wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36            20.7
# 1     white            6.3              0.30         0.34             1.6
# 2     white            8.1              0.28         0.40             6.9
# 3     white            7.2              0.23         0.32             8.5
# 4     white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
def get_missing_values(df):
    values = {}
    for feat in df.columns:
        if df[feat].isna().any():
            values[feat] = round(df[feat].mean(),2)
    return values

# %%
values = get_missing_values(df)

# %%
values
# Out:
# {'fixed acidity': 7.22,
#  'volatile acidity': 0.34,
#  'citric acid': 0.32,
#  'residual sugar': 5.44,
#  'chlorides': 0.06,
#  'pH': 3.22,
#  'sulphates': 0.53}

# %%
df.fillna(value=values,inplace=True)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
Sum = df.isnull().sum()
Percentage = ( df.isnull().sum()/df.isnull().count())

pd.concat([Sum,Percentage], axis =1, keys= ['Sum', 'Percentage'])
# Out:
#                       Sum  Percentage
# wine_type               0         0.0
# fixed acidity           0         0.0
# volatile acidity        0         0.0
# citric acid             0         0.0
# residual sugar          0         0.0
# chlorides               0         0.0
# free sulfur dioxide     0         0.0
# total sulfur dioxide    0         0.0
# density                 0         0.0
# pH                      0         0.0
# sulphates               0         0.0
# alcohol                 0         0.0
# quality                 0         0.0

# %%
sns.pairplot(df, hue="quality")

# %%
plt.figure(figsize=(10,5))
ax = df.corr()['quality'].plot(kind='bar',title='correlation of target variable to features')
ax.set_ylabel('correlation')
# Out:
# Text(0, 0.5, 'correlation')

# %%
#import ppscore as ps
plt.figure(figsize=(30,10));plt.subplot(121,title = 'Correletion plot')
sns.heatmap(df.corr(),annot=True);

# %%
df.head()
# Out:
#   wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36            20.7
# 1     white            6.3              0.30         0.34             1.6
# 2     white            8.1              0.28         0.40             6.9
# 3     white            7.2              0.23         0.32             8.5
# 4     white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df.wine_type = df.wine_type.map({'white':0, 'red':1})

# %%
df.head()
# Out:
#    wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0          0            7.0              0.27         0.36            20.7
# 1          0            6.3              0.30         0.34             1.6
# 2          0            8.1              0.28         0.40             6.9
# 3          0            7.2              0.23         0.32             8.5
# 4          0            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
sns.countplot(data=df, x="quality").set_title("Wine quality")
# Out:
# Text(0.5, 1.0, 'Wine quality')

# %%
# !pip install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-0.11.6.post3-py3-none-any.whl (86 kB)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from tpot) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from tpot) (0.23.2)
# Collecting deap>=1.2
#   Downloading deap-1.3.1-cp38-cp38-win_amd64.whl (108 kB)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from tpot) (4.49.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from tpot) (0.16.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from tpot) (1.1.0)
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from tpot) (1.2.1)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from tpot) (1.19.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.22.0->tpot) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.24.2->tpot) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.24.2->tpot) (2020.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from update-checker>=0.16->tpot) (2.24.0)
# Requirement already satisfied: six>=1.5 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\danie\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.25.10)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py): started
#   Building wheel for stopit (setup.py): finished with status 'done'
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11959 sha256=06375debbfa8329c235870f8768f970edecda26d851a7a25aeb3ad7cd54f19a4
#   Stored in directory: c:\users\danie\appdata\local\pip\cache\wheels\a8\bb\8f\6b9328d23c2dcedbfeb8498b9f650d55d463089e3b8fc0bfb2
# Successfully built stopit
# Installing collected packages: deap, update-checker, stopit, tpot
# Successfully installed deap-1.3.1 stopit-1.1.2 tpot-0.11.6.post3 update-checker-0.18.0
# WARNING: You are using pip version 20.2; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\danie\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import tpot
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X = df.drop(columns=['quality'],axis=1) 
y = df.quality

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=40)

# %%
lr = LogisticRegression(random_state=667)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=667)

# %%
train_accuracy = lr.score(X_train, y_train)
test_accuracy = lr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Accuracy in Train set   : 0.47
# Accuracy in Test  set   : 0.45

# %%
df_bins3= df.copy()

# %%
bins = [0,4,7,10]

labels = [0,1,2] # 'low'=0,'average'=1, 'high'=2

df_bins3['quality_range']= pd.cut(x=df_bins3['quality'], bins=bins, labels=labels)

#df_bins3.type = df_bins3.type.map({'white':0, 'red':1})

print(df_bins3[['quality_range','quality']].head(5))
# Out:
#   quality_range  quality
# 0             1        6
# 1             1        6
# 2             1        6
# 3             1        6
# 4             1        6

# %%
sns.countplot(data=df_bins3, x="quality_range").set_title("Wine quality")
# Out:
# Text(0.5, 1.0, 'Wine quality')

# %%
df_bins3 = df_bins3.drop(columns=['quality'],axis=1).copy()

# %%
X = df_bins3.drop(columns=['quality_range'],axis=1) 
y = df_bins3.quality_range

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=667)

# %%
X.columns
# Out:
# Index(['wine_type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
lr    = LogisticRegression(random_state=40)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=40)

# %%
train_accuracy = lr.score(X_train, y_train)
test_accuracy = lr.score(X_test, y_test)
print('One-vs-rest', '-'*35, 
      'Accuracy Score of Train Model : {:.2f}'.format(train_accuracy), 
      'Accuracy Score of Test  Model : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# One-vs-rest
# -----------------------------------
# Accuracy Score of Train Model : 0.00
# Accuracy Score of Test  Model : 0.00

# %%
AutoML = tpot.TPOTClassifier(
                            generations=5,
                            population_size=100,
                            offspring_size=None,
                            mutation_rate=0.9,
                            crossover_rate=0.1,
                            scoring=None,
                            cv=5,
                            subsample=1.0,
                            n_jobs=1,
                            max_time_mins=None,
                            max_eval_time_mins=5,
                            random_state=None,
                            config_dict=None,
                            template=None,
                            warm_start=False,
                            memory=None,
                            use_dask=False,
                            periodic_checkpoint_folder=None,
                            early_stop=None,
                            verbosity=2,
                            disable_update_check=False,
                            )

# %%
AutoML.fit(X_train,y_train)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=600.0, style=ProgressStyle(de…
# Generation 1 - Current best internal CV score: 0.9426591767231806

# %%
AutoML = tpot.TPOTClassifier(
                            generations=5,
                            population_size=100,
                            offspring_size=None,
                            mutation_rate=0.9,
                            crossover_rate=0.1,
                            scoring=None,
                            cv=5,
                            subsample=1.0,
                            n_jobs=1,
                            max_time_mins=None,
                            max_eval_time_mins=5,
                            random_state=None,
                            config_dict=None,
                            template=None,
                            warm_start=False,
                            memory=None,
                            use_dask=False,
                            periodic_checkpoint_folder=None,
                            early_stop=None,
                            verbosity=2,
                            disable_update_check=False,
                            )

# %%
AutoML.fit(X,y)
#save model 
with open('model-v1.pkl', 'wb') as f:
    joblib.dump(lr,f)
# Out:
# Warning: xgboost.XGBClassifier is not available and will not be used by TPOT.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=600.0, style=ProgressStyle(de…
# Generation 1 - Current best internal CV score: 0.9318147687570321
# Generation 2 - Current best internal CV score: 0.9318147687570321
# Generation 3 - Current best internal CV score: 0.9318147687570321
# Generation 4 - Current best internal CV score: 0.9318147687570321
# Generation 5 - Current best internal CV score: 0.9318147687570321
#
# Best pipeline: KNeighborsClassifier(input_matrix, n_neighbors=20, p=2, weights=uniform)

# %%
from sklearn.metrics import confusion_matrix as cm

predictions = AutoML.predict(X_test)
score = round(accuracy_score(y_test, predictions), 3)
cm1 = cm(y_test, predictions)
sns.heatmap(cm1, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size = 15)
plt.show()

# %%
AutoML.export('pipeline.py')
